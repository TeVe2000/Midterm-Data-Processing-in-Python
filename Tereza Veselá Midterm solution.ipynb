# %% [markdown]
# # Midterm - Tereza Veselá

# %%
import numpy as np
from collections import defaultdict
import csv
import os
import requests
import sys

# %matplotlib inline
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
import zipfile
import datetime

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'C:\\Users\\ttves\\Documents\\IES\\2023 2024 IES ZS - 2. roč\\Data Processing in Python'

# %%
list_of_files=["CTVA", "DIS", "EVRG", "LIN", "VLO"]
df=pd.DataFrame()
with zipfile.ZipFile("95965500.zip") as z:
    with z.open("data/CTVA.csv") as f: 
        CTVA =pd.read_csv(f,index_col=['Date'])
CTVA["ID"]="CTVA"
        
CTVA
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2019-05-24  32.000000  28.500000  29.750000  29.000000    44000.0  27.782021
# 2019-05-28  30.500000  28.510000  29.250000  28.764999    61500.0  27.556889
# 2019-05-29  29.900000  27.660000  29.900000  28.500000   207800.0  27.303020
# 2019-05-30  29.160000  28.219999  28.990000  28.799999   666000.0  27.590422
# 2019-05-31  28.590000  26.969999  28.500000  26.969999   853800.0  25.837276
# ...               ...        ...        ...        ...        ...        ...
# 2022-11-07  67.019997  65.260002  65.330002  66.040001  3421800.0  66.040001
# 2022-11-08  67.519997  65.879997  66.089996  67.190002  2901300.0  67.190002
# 2022-11-09  67.870003  66.735001  67.070000  67.050003  3595000.0  67.050003
# 2022-11-10  68.029999  66.529999  68.029999  67.209999  4523900.0  67.209999
# 2022-11-11  68.099998  64.294998  67.860001  64.769997  5138000.0  64.769997
#
#               ID
# Date
# ...

# %%
list_of_files=["CTVA", "DIS", "EVRG", "LIN", "VLO"]
df=pd.DataFrame()
with zipfile.ZipFile("95965500.zip") as z:
    with z.open("data/DIS.csv") as f: 
        DIS =pd.read_csv(f,index_col=['Date'])
DIS["ID"]="DIS"
        
DIS
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-11-13  105.139999  103.980003  104.139999  104.739998   7856000.0
# 2017-11-14  104.570000  103.000000  104.570000  103.169998   6929300.0
# 2017-11-15  103.959999  102.449997  102.750000  103.690002   5691500.0
# 2017-11-16  103.980003  102.760002  103.629997  103.599998   6410900.0
# 2017-11-17  103.989998  102.970001  103.220001  103.440002   7500800.0
# ...                ...         ...         ...         ...         ...
# 2022-11-07  101.559998   98.989998  100.879997  100.430000  11355200.0
# 2022-11-08  101.970001   98.050003  100.739998   99.900002  27130300.0
# 2022-11-09   91.099998   86.279999   90.550003   86.750000  62029800.0
# 2022-11-10   90.500000   87.610001   89.750000   90.459999  36968100.0
# 2022-11-11   95.580002   91.099998   91.580002   95.010002  22320900.0
#
#              Adj Close   ID
# Date
# 2017-11-13  101.047302  DIS
# 2017-11-14   99.532654  DIS
# ...

# %%
list_of_files=["CTVA", "DIS", "EVRG", "LIN", "VLO"]
df=pd.DataFrame()
with zipfile.ZipFile("95965500.zip") as z:
    with z.open("data/EVRG.csv") as f: 
        EVRG =pd.read_csv(f,index_col=['Date'])
EVRG["ID"]="EVRG"
        
EVRG
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2017-11-13  54.740002  53.869999  53.869999  54.720001   755000.0  47.549511
# 2017-11-14  55.509998  54.470001  54.509998  55.490002   808800.0  48.218613
# 2017-11-15  55.520000  55.160000  55.450001  55.400002   867300.0  48.140404
# 2017-11-16  55.910000  55.130001  55.299999  55.869999  1061900.0  48.548809
# 2017-11-17  55.799999  55.320000  55.709999  55.419998   668700.0  48.157772
# ...               ...        ...        ...        ...        ...        ...
# 2022-11-07  62.599998  60.459999  62.599998  61.240002  1444500.0  61.240002
# 2022-11-08  62.000000  61.060001  61.439999  61.480000  1873000.0  61.480000
# 2022-11-09  61.490002  59.439999  61.220001  60.130001  2902100.0  60.130001
# 2022-11-10  62.110001  59.669998  61.880001  61.700001  2212000.0  61.700001
# 2022-11-11  61.650002  58.910000  61.610001  59.389999  2466000.0  59.389999
#
#               ID
# Date
# ...

# %%
list_of_files=["CTVA", "DIS", "EVRG", "LIN", "VLO"]
df=pd.DataFrame()
with zipfile.ZipFile("95965500.zip") as z:
    with z.open("data/LIN.csv") as f: 
        LIN =pd.read_csv(f,index_col=['Date'])
LIN["ID"]="EVRG"
        
LIN
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-11-13  148.570007  145.740005  146.389999  148.149994  1455900.0
# 2017-11-14  147.830002  146.529999  147.809998  147.630005  1056100.0
# 2017-11-15  147.500000  145.869995  147.210007  146.169998  1943800.0
# 2017-11-16  149.080002  146.779999  147.500000  149.039993  1779900.0
# 2017-11-17  151.440002  149.039993  149.110001  150.639999  2930700.0
# ...                ...         ...         ...         ...        ...
# 2022-11-07  313.950012  309.420013  311.089996  313.489990  1575900.0
# 2022-11-08  318.510010  313.690002  314.700012  314.709991  1520000.0
# 2022-11-09  318.869995  313.329987  315.700012  314.440002  1165500.0
# 2022-11-10  330.130005  324.540009  330.000000  328.369995  2683400.0
# 2022-11-11  334.260010  329.489990  333.170013  330.220001  2133700.0
#
#              Adj Close    ID
# Date
# 2017-11-13  137.255859  EVRG
# 2017-11-14  136.774109  EVRG
# ...

# %%
list_of_files=["CTVA", "DIS", "EVRG", "LIN", "VLO"]
df=pd.DataFrame()
with zipfile.ZipFile("95965500.zip") as z:
    with z.open("data/VLO.csv") as f: 
        VLO =pd.read_csv(f,index_col=['Date'])
VLO["ID"]="VLO"
        
VLO
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-11-13   81.519997   80.610001   81.239998   80.669998  2568500.0
# 2017-11-14   81.589996   80.489998   80.550003   81.370003  3108700.0
# 2017-11-15   81.690002   80.000000   80.889999   81.480003  3122000.0
# 2017-11-16   82.610001   81.209999   81.309998   82.120003  4322600.0
# 2017-11-17   82.919998   81.750000   81.849998   82.879997  2897400.0
# ...                ...         ...         ...         ...        ...
# 2022-11-07  132.929993  128.820007  129.080002  131.779999  3767900.0
# 2022-11-08  133.110001  129.529999  131.820007  132.250000  3736900.0
# 2022-11-09  133.550003  127.260002  131.570007  128.000000  4125900.0
# 2022-11-10  132.600006  128.199997  130.720001  132.449997  2916300.0
# 2022-11-11  136.169998  132.699997  134.440002  133.960007  4438000.0
#
#              Adj Close   ID
# Date
# 2017-11-13   65.271454  VLO
# 2017-11-14   65.837830  VLO
# ...

# %%
CTVA.merge(DIS, left_on="Date", right_on="ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20980\2921145473.py in <module>
# ----> 1 CTVA.merge(DIS, left_on="Date", right_on="ID")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ...

# %%
url = f'https://ies-python-midterm.s3.eu-central-1.amazonaws.com/companies/companies_no_subindustry.csv'
        r = request.get(url)
# Out:
#   File "C:\Users\ttves\AppData\Local\Temp\ipykernel_20980\485773210.py", line 2
#     r = request.get(url)
#     ^
# IndentationError: unexpected indent

# %%
df = pd.read_csv('companies_no_subindustry.csv', sep = ',', on_bad_lines= 'skip')
df
# Out:
#     Symbol              Security             GICS_Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...

# %% [markdown]
# 1. Find out how many companies do not filled-in the date of inclusion (column
# “included”) to S&P 500.

# %%
df['included'].isna().sum()
# Out:
# 45

# %% [markdown]
# 2. Delete the companies with no inclusion date and calculate which company is the
# oldest/youngest constituent and tell us the average age of a constituent in the sample.

# %%
df_clean=df[~df['included'].isna()]
df_clean
# Out:
#     Symbol              Security             GICS_Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...

# %% [markdown]
# oldest constituent

# %%
date_old=df_clean['included'].min()
date_old
# Out:
# '01.01.1994'

# %%
df_clean.head()
# Out:
#   Symbol     Security  GICS_Sector                       hq    included  \
# 0    MMM           3M  Industrials    Saint Paul, Minnesota  09.08.1976
# 1    AOS  A. O. Smith  Industrials     Milwaukee, Wisconsin  26.07.2017
# 2    ABT       Abbott  Health Care  North Chicago, Illinois  31.03.1964
# 3   ABBV       AbbVie  Health Care  North Chicago, Illinois  31.12.2012
# 4   ABMD      Abiomed  Health Care   Danvers, Massachusetts  31.05.2018
#
#        Founded
# 0         1902
# 1         1916
# 2         1888
# 3  2013 (1888)
# 4         1981

# %%
df_clean.loc['01.01.1994']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '01.01.1994'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20980\2495134457.py in <module>
# ----> 1 df_clean.loc['01.01.1994']
#
# ...

# %% [markdown]
# youngest constituent

# %%
date_young=df_clean['included'].max()
date_young
# Out:
# '31.12.2012'

# %%
df_clean.loc['31.12.2012']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '31.12.2012'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20980\4135314401.py in <module>
# ----> 1 df_clean.loc['31.12.2012']
#
# ...

# %% [markdown]
# average company age

# %%
df['Founded'] = df['Year'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
